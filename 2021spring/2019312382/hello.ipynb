# %% [markdown]
# 斐波那契

# %%
def FIB(num):
    result = [1,1]
    for i in range(num-2):
        result.append(result[-2]+result[-1])
    return result
def Product(list):
    result=1
    for i in range(len(list)):
        result = list[i]*result
    return result

# %%
Product(FIB(1000))
# Out:
# ...
