# %%
##计算斐波拉契乘积##

# %%
a=1
b=2
product=a*b
j=int(input("please input the number:"))
for i in range(j):
    a=a+b
    a=a+b
    b=a-b
    a=a-b
    product=product*b
product
# Out:
# please input the number:123
# ...
