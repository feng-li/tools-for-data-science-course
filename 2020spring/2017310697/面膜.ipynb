# %%
import numpy as np
from scipy.stats import expon
import matplotlib.pyplot as plt
x = np.linspace(expon.ppf(0.01), #ppf stands for percentiles.
                expon.ppf(0.99), 100)

fig, ax = plt.subplots(1, 1)
ax.plot(x, expon.pdf(x),
        'red', lw=1, alpha=0.7, label='norm pdf')
plt.show()

# %%
r = norm.rvs(loc=10, scale=100, size=1000)
fig, ax = plt.subplots(1, 1)
ax.hist(r, normed=True, histtype='stepfilled', alpha=1.5, label='...')
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
years = [1950, 1960, 1970, 1980, 1990, 2000, 2010]
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]
# create a line chart, years on x-axis, gdp on y-axis
fig = plt.figure()
plt.plot(years, gdp, color='red', marker='x', linestyle='solid')
# add a title
plt.title("Nominal GDP")
# add a label to the y-axis
plt.ylabel("Billions of $")
plt.show()

# %%
from scipy import special
def drumhead_height(n, k, distance, angle, t):
   kth_zero = special.jn_zeros(n, k)[-1]
   return np.cos(t) * np.cos(n*angle) * special.jn(n, distance*kth_zero)
theta = np.r_[0:2*np.pi:100j]
radius = np.r_[0:1:100j]
x = np.array([r * np.cos(theta) for r in radius])
y = np.array([r * np.sin(theta) for r in radius])
z = np.array([drumhead_height(1, 1, r, theta, 0.5) for r in radius])

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
fig = plt.figure()
ax = Axes3D(fig)
ax.plot_surface(x, y, z, rstride=2, cstride=2, cmap=cm.jet)
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
import pandas as pd
from scipy import stats, integrate
import seaborn as sns
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "distributions")))

# %%
x = np.random.beta(size=100,a=10,b=2)
sns.distplot(x);

# %%
sns.distplot(x, kde=False, rug=True);

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
sns.pairplot(tips)

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot, cmap="Greens_d", n_levels=6)

# %%
import matplotlib as mpl
sns.set(style="darkgrid", color_codes=True)
np.random.seed(sum(map(ord, "categorical")))
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.stripplot(x="sex", y="age", data=titanic)

# %%
sns.swarmplot(x="sex", y="age", data=titanic)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.violinplot(x="age", y="sex", hue="survived", data=titanic)

# %%
sns.violinplot(x="sex",y="age",data=titanic,inner=None)
sns.swarmplot(x="sex",y="age",data=titanic,color="r",alpha=0.5)

# %%
sns.factorplot(x="class", y="age", hue="survived",
               col="sex", data=titanic, kind="box", size=4, aspect=.5)

# %%
sns.set(color_codes=True)
np.random.seed(sum(map(ord, "regression")))
sns.regplot(x="age", y="survived", data=titanic)

# %%
sns.lmplot(x="age", y="survived", hue="sex", data=titanic)

# %%
sns.lmplot(x="age",y="survived",hue="sex",data=titanic,markers=["o","x"],palette="Set1")

# %%
sns.lmplot(x="age",y="survived",hue="sex",col="class",data=titanic)

# %%
sns.jointplot(x="age", y="survived", data=titanic, kind="reg")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from pylab import *  
mpl.rcParams['font.sans-serif'] = ['SimHei'] 
plt.rcParams['axes.unicode_minus'] = False 
mask = pd.read_csv('mask.csv',encoding="gbk")   
mask.tail()
# Out:
#       名称     价格   月销量   评价数 店铺所在地  适合肤质  产地  补水保湿  美白提亮  控油祛痘  清洁毛孔  提拉紧致
# 789  自然堂  122.0  1077  1715    上海  任何肤质  中国     1     1     0     0     0
# 790  自然堂  112.5   232  1887    上海  任何肤质  中国     1     0     0     1     0
# 791  自然堂   29.0   282   297    上海  任何肤质  中国     1     1     1     1     1
# 792  自然堂  173.0  1002  2389    浙江  任何肤质  中国     1     1     0     0     0
# 793  自然堂  119.0   100   106    浙江  任何肤质  中国     1     1     1     0     0

# %%
mask.info()
print(mask['产地'].unique())
print(mask['店铺所在地'].unique())
print(mask['适合肤质'].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794 entries, 0 to 793
# Data columns (total 12 columns):
# 名称       794 non-null object
# 价格       794 non-null float64
# 月销量      794 non-null int64
# 评价数      794 non-null int64
# 店铺所在地    794 non-null object
# 适合肤质     794 non-null object
# 产地       794 non-null object
# 补水保湿     794 non-null int64
# 美白提亮     794 non-null int64
# 控油祛痘     794 non-null int64
# 清洁毛孔     794 non-null int64
# 提拉紧致     794 non-null int64
# dtypes: float64(1), int64(7), object(4)
# memory usage: 74.6+ KB
# ['中国' '日本' '韩国' '美国' '英国' '其他/other']
# ['湖南' '浙江' '英国' '安徽' '广东' '湖北' '江苏' '上海' '江西' '北京' '海外' '天津' '山东' '河南'
#  '新加坡' '河北' '辽宁' '四川' '重庆' '福建' '内蒙古' '海南' '云南' '广西' '陕西' '黑龙江']
# ['任何肤质' '干性肤质' '油性及混合性肤质' '中性及干性肤质' '混合型肤质' '敏感性肤质' '中性肤质' '油性肤质']

# %%
mask.loc[mask.店铺所在地 == '英国','店铺所在地'] = '海外'
mask.loc[mask.店铺所在地 == '新加坡','店铺所在地'] = '海外'
print(mask['店铺所在地'].unique())
# Out:
# ['湖南' '浙江' '海外' '安徽' '广东' '湖北' '江苏' '上海' '江西' '北京' '天津' '山东' '河南' '河北'
#  '辽宁' '四川' '重庆' '福建' '内蒙古' '海南' '云南' '广西' '陕西' '黑龙江']

# %%
mask.loc[mask.产地 == '其他/other','产地'] = '其他'
mask.loc[mask.适合肤质 != '任何肤质','适合肤质'] = '其他'

# %%
plt.figure(figsize=(12,5))
sns.countplot('产地',data=mask,order = mask['产地'].value_counts().index,palette='Blues_r')

# %%
from numpy import median
fig=plt.figure(figsize=(16,16))
ax=fig.add_subplot(3,1,1)
salesdata = mask[['店铺所在地','月销量']].groupby(['店铺所在地']).mean().sort_values(by='月销量',ascending = False).reset_index()
g = sns.barplot(x="店铺所在地", y="月销量",data=salesdata, palette="Paired")
for index,row in bardata.iterrows():
    g.text(row.name,row.月销量,int(row.月销量),color="black",ha="center") 
ax=fig.add_subplot(3,1,2)
sns.barplot(x="店铺所在地", y="月销量",hue="适合肤质", data=mask, estimator=median,ci=20)
ax=fig.add_subplot(3,1,3)
pricedata = mask[['店铺所在地','价格']].groupby(['店铺所在地']).mean().sort_values(by='价格',ascending = False).reset_index()
g = sns.barplot(x="店铺所在地", y="价格",data=pricedata, palette="Paired")
for index,row in pricedata.iterrows():
    g.text(row.name,row.价格,int(row.价格),color="black",ha="center")
plt.show()

# %%
fig=plt.figure(figsize=(16,20))
ax=fig.add_subplot(2,1,1)
ax.bar(x=salesdata.店铺所在地,height=bardata.月销量)
for index,row in salesdata.iterrows():
    ax.text(row.name,row.月销量,int(row.月销量),color="black",ha="center")
ax.set_title('column')
ax.set_ylabel('平均月销量')
ax.set_xlabel('店铺所在地')
ax=fig.add_subplot(2,1,2)
ax.barh(y = range(salesdata.shape[0]),width = salesdata.月销量,tick_label = salesdata.店铺所在地,color = 'steelblue')
for index,row in salesdata.iterrows():
    ax.text(row.月销量,row.name,int(row.月销量),color="black",va="center") #va调整位置
ax.set_title('row')
ax.set_ylabel('店铺所在地')
ax.set_xlabel('平均月销量')
plt.show()

# %%
fig=plt.figure(figsize=(16,40))
ax=fig.add_subplot(5,1,1)
sns.boxplot(data=mask,x='店铺所在地',y=log(mask['价格']),hue='补水保湿',notch = True) 
plt.ylabel('log(价格)')
ax=fig.add_subplot(5,1,2)
sns.boxplot(data=mask,x='店铺所在地',y=log(mask['价格']),hue='美白提亮',notch = True) 
plt.ylabel('log(价格)')
ax=fig.add_subplot(5,1,3)
sns.boxplot(data=mask,x='店铺所在地',y=log(mask['价格']),hue='控油祛痘',notch = True) 
plt.ylabel('log(价格)')
ax=fig.add_subplot(5,1,4)
sns.boxplot(data=mask,x='店铺所在地',y=log(mask['价格']),hue='清洁毛孔',notch = True) 
plt.ylabel('log(价格)')
ax=fig.add_subplot(5,1,5)
sns.boxplot(data=mask,x='店铺所在地',y=log(mask['价格']),hue='提拉紧致',notch = True) 
plt.ylabel('log(价格)')
# Out:
# Text(0, 0.5, 'log(价格)')

# %%
sns.boxenplot(x='产地',y=log(mask['价格']),data=mask,palette="Set1")
plt.ylabel('log(价格)')
# Out:
# Text(0, 0.5, 'log(价格)')

# %%
fig=plt.figure(figsize=(16,16))
ax=fig.add_subplot(2,1,1)
plt.hist(mask['月销量'],bins=30,density=True,color='b',alpha=0.5)
ax.set_xlabel("月销量")
ax.set_ylabel("频率")
ax=fig.add_subplot(2,1,2)
plt.hist(mask['价格'],bins=30,density=True,color='g',alpha=0.5)
ax.set_xlabel("价格")
ax.set_ylabel("频率")
# Out:
# Text(0, 0.5, '频率')

# %%
sns.pairplot(mask[['月销量','评价数','价格']])

# %%
g = sns.PairGrid(mask[['评价数','价格']])
g.map_diag(sns.distplot) 
g.map_upper(plt.scatter) 
g.map_lower(sns.kdeplot)
