# %%
import requests

# %%
r = requests.get("http://www.686ppt.com/s-1-0-14-0-0-0-0.html")
r.status_code
# Out:
# 200

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '<!doctype html>\r\n<html>\r\n<head>\r\n        <script type="text/javascript">\r\n        window._agl = window._agl || [];\r\n        (function () {\r\n            _agl.push(\r\n                [\'production\', \'_f7L2XwGXjyszb4d1e2oxPybgD\']\r\n            );\r\n            (function () {\r\n                var agl = document.createElement(\'script\');\r\n                agl.type = \'text/javascript\';\r\n                agl.async = true;\r\n                agl.src = \'https://fxgate.baidu.com/angelia/fcagl.js?production=_f7L2XwGXjyszb4d1e2oxPybgD\';\r\n                var s = document.getElementsByTagName(\'script\')[0];\r\n                s.parentNode.insertBefore(agl, s);\r\n            })();\r\n        })();\r\n    </script>\r\n<script src="/template/tgtongji.js?731600264"></script>\r\n  <meta charset="utf-8">\r\n  <title>PPT模板-免费PPT模板下载-PPT模板免费下载-芒果派</title>\r\n  <meta name="title" content="PPT模板-免费PPT模板下载-PPT模板免费下载-芒果派" />\r\n  <meta name="keywords" content="" />\r\n  <meta n
# ...

# %%
r.headers
# Out:
# {'Server': 'Tengine', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': 'sec_tc=AQAAAO0T7moEjw4AMXN03cmWvetx4tWp; Path=/; Expires=Fri, 08-May-20 16:05:05 GMT; HttpOnly, ZDEDebuggerPresent=php,phtml,php3; path=/', 'Date': 'Fri, 08 May 2020 15:55:06 GMT', 'X-Powered-By': 'PHP/5.3.29', 'Ali-Swift-Global-Savetime': '1588953306', 'Via': 'cache10.l2st4-4[713,200-0,M], cache10.l2st4-4[713,0], skunlun4.cn49[774,200-0,M], skunlun7.cn49[775,0]', 'X-Cache': 'MISS TCP_MISS dirn:-2:-2', 'X-Swift-SaveTime': 'Fri, 08 May 2020 15:55:06 GMT', 'X-Swift-CacheTime': '0', 'Timing-Allow-Origin': '*', 'EagleId': 'ca644acf15889533059547740e'}

# %%
r.content
# Out:
# b'<!doctype html>\r\n<html>\r\n<head>\r\n        <script type="text/javascript">\r\n        window._agl = window._agl || [];\r\n        (function () {\r\n            _agl.push(\r\n                [\'production\', \'_f7L2XwGXjyszb4d1e2oxPybgD\']\r\n            );\r\n            (function () {\r\n                var agl = document.createElement(\'script\');\r\n                agl.type = \'text/javascript\';\r\n                agl.async = true;\r\n                agl.src = \'https://fxgate.baidu.com/angelia/fcagl.js?production=_f7L2XwGXjyszb4d1e2oxPybgD\';\r\n                var s = document.getElementsByTagName(\'script\')[0];\r\n                s.parentNode.insertBefore(agl, s);\r\n            })();\r\n        })();\r\n    </script>\r\n<script src="/template/tgtongji.js?731600264"></script>\r\n  <meta charset="utf-8">\r\n  <title>PPT\xe6\xa8\xa1\xe6\x9d\xbf-\xe5\x85\x8d\xe8\xb4\xb9PPT\xe6\xa8\xa1\xe6\x9d\xbf\xe4\xb8\x8b\xe8\xbd\xbd-PPT\xe6\xa8\xa1\xe6\x9d\xbf\xe5\x85\x8d\xe8\xb4\xb9\x
# ...

# %%
from urllib.request import urlopen
html = urlopen("http://www.686ppt.com/s-1-0-14-0-0-0-0.html")
print(html.read())
# Out:
# b'<html><script>function sck(sec) {var qw,we="",er="\\x14\\x1f\\x13\\x05\\x1d\\x15\\x1e\\x04\\x5e\\x13\\x1f\\x1f\\x1b\\x19\\x15\\x4d\\x52\\x03\\x15\\x13\\x4d\\x45\\x15\\x12\\x45\\x48\\x41\\x43\\x45\\x43\\x41\\x42\\x49\\x11\\x15\\x43\\x16\\x43\\x41\\x41\\x16\\x15\\x15\\x11\\x12\\x41\\x49\\x15\\x13\\x14\\x40\\x16\\x43\\x42\\x40\\x48\\x12\\x43\\x45\\x40\\x44\\x4b\\x00\\x11\\x04\\x18\\x4d\\x5f\\x52\\x4b\\x07\\x19\\x1e\\x14\\x1f\\x07\\x5e\\x1c\\x1f\\x13\\x11\\x04\\x19\\x1f\\x1e\\x5e\\x02\\x15\\x1c\\x1f\\x11\\x14\\x58\\x59";for(qw=0;qw<er.length;qw++) {we+=String.fromCharCode(er.charCodeAt(qw)^sec&0xff);};eval(we);};sck(5744);</script></html>'

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.686ppt.com/")
bs = BeautifulSoup(html.read(),'html.parser')
print(bs)
# Out:
# <html><script>function sck(sec) {var qw,we="",er="";for(qw=0;qw<er.length;qw++) {we+=String.fromCharCode(er.charCodeAt(qw)^sec&0xff);};eval(we);};sck(3178);</script></html>

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.686ppt.com/")
bs = BeautifulSoup(html.read(),'html.parser')
namelist= bs.findAll('div',{'class':'modelList'})
for name in namelist:
    print(name.get_text())
# Out:
# PPT精选模板
#
#
# 工作总结
# 培训
# 快闪
# 竞聘
# 自我介绍
# 幼儿园
# 查看更多>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 经典蓝色商务风年终工作总结扬帆起航再创辉煌PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 坚守廉洁心杜绝微腐败 一不忘出席，严于律己，做一名合格的共产党员一党建党课学习 （含Word演讲稿）PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 开学第一课复课开学防控疫情PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 致敬平凡劳动者的不平凡作为劳动节特别篇PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 高中开学第一课高中开学复学教育PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 原创极简手绘创意风汇报总结PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 卡通向劳动者致敬劳动节主题模板PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 复课开学防控疫情开学第一课加强疫情防控共建平安校园PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 职业病防治法宣传周职业病防治法知识PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 复课开学防控疫情开学第一课加强疫情防控共建平安校园PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 纪念“五四运动” 101周年弘扬五四精神争做合格团员PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 劳动节致敬平凡劳动者的不平凡作为PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# 原创小清新唯美花朵工作总结PPT模板
#
#
#
#
#
#
#
#
#
#
#
#
# 立即下载
#
#
#
#
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

html = urlopen("http://www.686ppt.com/")
bs = BeautifulSoup(html.read(),'html.parser')
namelist= bs.findAll('div',{'class':'modelList'})

# %%
import requests
r = requests.get("http://python123.io/ws/demo.html")
r.status_code
# Out:
# 200

# %%
r.text
# Out:
# '<html><head><title>This is a python demo page</title></head>\r\n<body>\r\n<p class="title"><b>The demo python introduces several python courses.</b></p>\r\n<p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:\r\n<a href="http://www.icourse163.org/course/BIT-268001" class="py1" id="link1">Basic Python</a> and <a href="http://www.icourse163.org/course/BIT-1001870001" class="py2" id="link2">Advanced Python</a>.</p>\r\n</body></html>'

# %%
r.headers
# Out:
# {'Vary': 'Accept-Encoding', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, POST, PUT, PATCH, DELETE, OPTIONS', 'Access-Control-Allow-Headers': 'Cache-Control, Content-Type, Content-Length, Authorization, Accept, X-Requested-With, x-exam-system-code', 'Access-Control-Max-Age': '1728000', 'Content-Length': '532', 'Last-Modified': 'Sat, 25 Feb 2017 08:03:54 GMT', 'Cache-Control': 'max-age=0', 'Content-Type': 'text/html; charset=utf-8', 'Date': 'Fri, 08 May 2020 16:16:25 GMT', 'Connection': 'keep-alive'}

# %%
demo = r.text

# %%
demo
# Out:
# '<html><head><title>This is a python demo page</title></head>\r\n<body>\r\n<p class="title"><b>The demo python introduces several python courses.</b></p>\r\n<p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:\r\n<a href="http://www.icourse163.org/course/BIT-268001" class="py1" id="link1">Basic Python</a> and <a href="http://www.icourse163.org/course/BIT-1001870001" class="py2" id="link2">Advanced Python</a>.</p>\r\n</body></html>'

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(demo,"html.parser")
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    This is a python demo page
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The demo python introduces several python courses.
#    </b>
#   </p>
#   <p class="course">
#    Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
#    <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">
#     Basic Python
#    </a>
#    and
#    <a class="py2" href="http://www.icourse163.org/course/BIT-1001870001" id="link2">
#     Advanced Python
#    </a>
#    .
#   </p>
#  </body>
# </html>

# %%
import requests
from bs4 import BeautifulSoup
r= requests.get("http://www.686ppt.com/")
demo=r.text
soup = BeautifulSoup(demo,"html.parser")   #这里的html.parser是其中一个解析器，比较常用
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <script type="text/javascript">
#    window._agl = window._agl || [];
#         (function () {
#             _agl.push(
#                 ['production', '_f7L2XwGXjyszb4d1e2oxPybgD']
#             );
#             (function () {
#                 var agl = document.createElement('script');
#                 agl.type = 'text/javascript';
#                 agl.async = true;
#                 agl.src = 'https://fxgate.baidu.com/angelia/fcagl.js?production=_f7L2XwGXjyszb4d1e2oxPybgD';
#                 var s = document.getElementsByTagName('script')[0];
#                 s.parentNode.insertBefore(agl, s);
#             })();
#         })();
#   </script>
#   <script src="/template/tgtongji.js?448728434">
#   </script>
#   <meta charset="utf-8"/>
#   <title>
#    芒果派-全国专业PPT模板下载网站-海量精品PPT模板免费下载
#   </title>
#   <meta content="芒果派全国专业PPT模板下载网站-海量精品PPT模板免费下载" name="title">
#    <meta content="芒果派" name="keywords"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
r = requests.get("http://python123.io/ws/demo.html")
demo = r.text
print(demo)
# Out:
# <html><head><title>This is a python demo page</title></head>
# <body>
# <p class="title"><b>The demo python introduces several python courses.</b></p>
# <p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
# <a href="http://www.icourse163.org/course/BIT-268001" class="py1" id="link1">Basic Python</a> and <a href="http://www.icourse163.org/course/BIT-1001870001" class="py2" id="link2">Advanced Python</a>.</p>
# </body></html>

# %%
import requests
from bs4 import BeautifulSoup
r = requests.get("http://www.686ppt.com")
demo = r.text
print(demo)
# Out:
# <!doctype html>
# <html>
# <head>
#         <script type="text/javascript">
#         window._agl = window._agl || [];
#         (function () {
#             _agl.push(
#                 ['production', '_f7L2XwGXjyszb4d1e2oxPybgD']
#             );
#             (function () {
#                 var agl = document.createElement('script');
#                 agl.type = 'text/javascript';
#                 agl.async = true;
#                 agl.src = 'https://fxgate.baidu.com/angelia/fcagl.js?production=_f7L2XwGXjyszb4d1e2oxPybgD';
#                 var s = document.getElementsByTagName('script')[0];
#                 s.parentNode.insertBefore(agl, s);
#             })();
#         })();
#     </script>
# <script src="/template/tgtongji.js?794957257"></script>
#   <meta charset="utf-8">
#   <title>芒果派-全国专业PPT模板下载网站-海量精品PPT模板免费下载</title>
#   <meta name="title" content="芒果派全国专业PPT模板下载网站-海量精品PPT模板免费下载" />
#   <meta name="keywords" content="芒果派" />
# ...

# %%
import requests
from bs4 import BeautifulSoup
r = requests.get("http://python123.io/ws/demo.html")
demo = r.text
print(demo)
# Out:
# <html><head><title>This is a python demo page</title></head>
# <body>
# <p class="title"><b>The demo python introduces several python courses.</b></p>
# <p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
# <a href="http://www.icourse163.org/course/BIT-268001" class="py1" id="link1">Basic Python</a> and <a href="http://www.icourse163.org/course/BIT-1001870001" class="py2" id="link2">Advanced Python</a>.</p>
# </body></html>

# %%
soup = BeautifulSoup(demo,'html.parser')

# %%
print(soup)
# Out:
# <html><head><title>This is a python demo page</title></head>
# <body>
# <p class="title"><b>The demo python introduces several python courses.</b></p>
# <p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
# <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a> and <a class="py2" href="http://www.icourse163.org/course/BIT-1001870001" id="link2">Advanced Python</a>.</p>
# </body></html>

# %%
soup.title
# Out:
# <title>This is a python demo page</title>

# %%
soup.a
# Out:
# <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>

# %%
soup.a.name
# Out:
# 'a'

# %%
soup.a.parent.name
# Out:
# 'p'

# %%
tag = soup.a

# %%
tag.attrs
# Out:
# {'href': 'http://www.icourse163.org/course/BIT-268001',
#  'class': ['py1'],
#  'id': 'link1'}

# %%
soup.a
# Out:
# <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a>

# %%
soup.a.string
# Out:
# 'Basic Python'

# %%
soup.a.name
# Out:
# 'a'

# %%
soup.p
# Out:
# <p class="title"><b>The demo python introduces several python courses.</b></p>

# %%
soup.p.string
# Out:
# 'The demo python introduces several python courses.'

# %%
soup.head
# Out:
# <head><title>This is a python demo page</title></head>

# %%
soup.head.contents
# Out:
# [<title>This is a python demo page</title>]

# %%
print(soup.head.children)

# %%
soup.body.contents
# Out:
# ['\n',
#  <p class="title"><b>The demo python introduces several python courses.</b></p>,
#  '\n',
#  <p class="course">Python is a wonderful general-purpose programming language. You can learn Python from novice to professional by tracking the following courses:
#  <a class="py1" href="http://www.icourse163.org/course/BIT-268001" id="link1">Basic Python</a> and <a class="py2" href="http://www.icourse163.org/course/BIT-1001870001" id="link2">Advanced Python</a>.</p>,
#  '\n']
