# %%
import csv
import jieba
with open('test1.csv','r')as f:
    f_csv = csv.reader(f)
    for row in f_csv:
        for i in row:
            print(i)
        print("\n")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-aa32ac9a210a> in <module>()
#       1 import csv
# ----> 2 import jieba
#       3 with open('test1.csv','r')as f:
#       4     f_csv = csv.reader(f)
#       5     for row in f_csv:
#
# ModuleNotFoundError: No module named 'jieba'

# %%
sentence=""
with open('test1.csv','r')as f:
    f_csv = csv.reader(f)
    for row in f_csv:
        if row!=[]:
            sentence+=row[0]+row[3]
jieba.analyse.extract_tags(sentence, topK=15, withWeight=False, allowPOS=())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2c96a8e2c159> in <module>()
#       5         if row!=[]:
#       6             sentence+=row[0]+row[3]
# ----> 7 jieba.analyse.extract_tags(sentence, topK=15, withWeight=False, allowPOS=())
#
# NameError: name 'jieba' is not defined
