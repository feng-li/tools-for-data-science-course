# %% [markdown]
# Webdriver   Feng.Li示例

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://www.bing.com/")

# %%
driver.find_element_by_id("sb_form_q").send_keys("feng li cufe")

# %%
driver.find_element_by_id("sb_form_go").click()

# %%
#driver.close()
#driver.quit()

# %% [markdown]
# 自写：

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("http://www.baidu.com/")

# %%
driver.find_element_by_id('kw').send_keys('python')
driver.find_element_by_id("su").click()

# %%
driver.quit()

# %% [markdown]
# 自写 爬校园门户：

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://authserver.cufe.edu.cn/authserver/login?service=http%3A%2F%2Fi.cufe.edu.cn%2Flogin")
driver.find_element_by_id('username').send_keys('2016310895')
driver.find_element_by_id('password').send_keys('A8238079l520cy')
driver.find_element_by_id("submit").click()

# %%
results = driver.find_element_by_xpath('//*[@id="bmxx"]/div[2]/div[1]/ul[1]/li[2]/div[1]/div[3]/div')

#results = driver.find_element_by_css_selector(".alert_msg.fl")
##################################
# 在获取包含多个class名称的tag对象时，建议使用：
# find_element_by_css_selector(".xx.xxx.xxxxx")或者
# find_element_by_css_selector("[class='xx xxx xxxxx']")

# %%
#print(results)        #错误输出
print(results.text)
# Out:
# 余额：26.55元

# %%
driver.quit()

# %% [markdown]
# 登陆邮箱

# %%
from selenium import webdriver
driver = webdriver.Chrome()
driver.get("https://mail.163.com/")
driver.find_element_by_id('auto-id-1559115788830').send_keys('15611876029')
driver.find_element_by_id('auto-id-1559115788802').send_keys('a8238079l520cy')
driver.find_element_by_id("submit").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-24-04701484592a> in <module>
#       2 driver = webdriver.Chrome()
#       3 driver.get("https://mail.163.com/")
# ----> 4 driver.find_element_by_id('auto-id-1559115788830').send_keys('15611876029')
#       5 driver.find_element_by_id('auto-id-1559115788802').send_keys('a8238079l520cy')
#       6 driver.find_element_by_id("submit").click()
#
# D:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     358             element = driver.find_element_by_id('foo')
#     359         """
# --> 360         return self.find_element(by=By.ID, value=id_)
#     361
#     362     def find_elements_by_id(self, id_):
#
# D:\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...
